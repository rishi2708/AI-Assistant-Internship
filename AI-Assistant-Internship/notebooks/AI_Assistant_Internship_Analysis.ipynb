# %% [markdown]
# # AI Assistant Internship Analysis
#
# This notebook documents the problem statement, datasets, methodology, model comparison, metrics, and visual outputs for the integrated AI Assistant project.

# %% [markdown]
# ## Problem Statement
#
# Build one AI Assistant that supports general conversation, MedQuAD medical Q&A, arXiv scientific Q&A, dynamic document ingestion, multimodal image reasoning, multilingual conversation, sentiment-aware response, memory, and analytics.

# %% [markdown]
# ## Datasets
#
# - MedQuAD: medical question-answer records.
# - arXiv: scientific paper metadata and abstracts.
# - User uploads: PDF, TXT, MD, DOCX documents.

# %%
from pathlib import Path
import json

root = Path('..')
metrics = json.loads((root / 'reports' / 'evaluation_metrics.json').read_text())
metrics

# %% [markdown]
# ## Methodology
#
# Document Loader -> Cleaning -> Chunking -> Embeddings -> FAISS -> Retriever -> Gemini -> Answer with citations.

# %% [markdown]
# ## Visual Outputs
#
# The repository includes SVG visual outputs in `images/`:
#
# - `sentiment_distribution.svg`
# - `confusion_matrix.svg`
# - `model_comparison.svg`

# %% [markdown]
# ## Model Comparison
#
# See `reports/model_comparison.md` and `reports/model_comparison.csv` for baseline vs advanced assistant comparison.
